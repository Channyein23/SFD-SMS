# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
temperature = ctrl.Antecedent(np.arange(0, 101, 1), 'temperature')
humidity = ctrl.Antecedent(np.arange(0, 101, 1), 'humidity')
result = ctrl.Consequent(np.arange(0, 101, 1), 'result', defuzzify_method='centroid')
temperature['verycold'] = fuzz.trapmf(temperature.universe, [0, 0, 10, 20])
temperature['cold'] = fuzz.trimf(temperature.universe, [10, 20, 30])
temperature['normal'] = fuzz.trimf(temperature.universe, [20, 30, 40])
temperature['hot'] = fuzz.trimf(temperature.universe, [30, 40, 50])
temperature['veryhot'] = fuzz.trapmf(temperature.universe, [40, 50, 100, 100])
humidity['dry'] = fuzz.trapmf(humidity.universe, [0, 0, 20, 40])
humidity['medium'] = fuzz.trimf(humidity.universe, [20, 40, 60])
humidity['wet'] = fuzz.trapmf(humidity.universe, [40, 60, 100, 100])
result['low'] = fuzz.trapmf(result.universe, [0, 0, 20, 40])
result['medium'] = fuzz.trimf(result.universe, [20, 40, 60])
result['high'] = fuzz.trapmf(result.universe, [40, 60, 100, 100])

# %%
temperature.view()
humidity.view()
result.view()
# Out:
# C:\Users\DELL\Anaconda3\envs\project1\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1 = ctrl.Rule(temperature['verycold'] & humidity['dry'], result['low'])
rule2 = ctrl.Rule(temperature['verycold'] & humidity['medium'], result['low'])
rule3 = ctrl.Rule(temperature['verycold'] & humidity['wet'], result['low'])
rule4 = ctrl.Rule(temperature['cold'] & humidity['dry'], result['low'])
rule5 = ctrl.Rule(temperature['cold'] & humidity['medium'], result['low'])
rule6 = ctrl.Rule(temperature['cold'] & humidity['wet'], result['low'])
rule7 = ctrl.Rule(temperature['normal'] & humidity['dry'], result['medium']
rule8 = ctrl.Rule(temperature['normal'] & humidity['medium'], result['low'])
rule9 = ctrl.Rule(temperature['normal'] & humidity['wet'], result['low'])
rule10 = ctrl.Rule(temperature['hot'] & humidity['dry'], result['high'])
rule11 = ctrl.Rule(temperature['hot'] & humidity['medium'], result['medium'])
rule12 = ctrl.Rule(temperature['hot'] & humidity['wet'], result['low'])
rule13 = ctrl.Rule(temperature['veryhot'] & humidity['dry'], result['high'])
rule14 = ctrl.Rule(temperature['veryhot'] & humidity['medium'], result['high'])
rule15 = ctrl.Rule(temperature['veryhot'] & humidity['wet'], result['high'])
# Out:
#   File "<ipython-input-12-bae917bcd4b8>", line 8
#     rule8 = ctrl.Rule(temperature['normal'] & humidity['medium'], result['medium'])
#         ^
# SyntaxError: invalid syntax

# %%
resulting_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15])
resulting = ctrl.ControlSystemSimulation(resulting_ctrl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c91affd4956f> in <module>
# ----> 1 resulting_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15])
#       2 resulting = ctrl.ControlSystemSimulation(resulting_ctrl)
#
# NameError: name 'rule10' is not defined

# %%
# Pass inputs to the ControlSystem using Antecedent labels with Pythonic API
# Note: if you like passing many inputs all at once, use .inputs(dict_of_data)
resulting.input['temperature'] = 44
resulting.input['humidity'] = 43

# Crunch the numbers
resulting.compute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fdef2f44159f> in <module>
#       1 # Pass inputs to the ControlSystem using Antecedent labels with Pythonic API
#       2 # Note: if you like passing many inputs all at once, use .inputs(dict_of_data)
# ----> 3 resulting.input['temperature'] = 44
#       4 resulting.input['humidity'] = 43
#       5
#
# NameError: name 'resulting' is not defined

# %%
resulting.output['result']
# Out:
# 59.4108527131784

# %%
print(resulting.output['result'])
result.view(sim=resulting)
# Out:
# 59.4108527131784

# %%
a = None
if not a:
    print('Chihuahua')
# Out:
# Chihuahua

# %%
'hello'.encode('utf-8')
# Out:
# b'hello'
